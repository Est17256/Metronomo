# %% [markdown]
# # Luis Esturban 17256
# ## Discord: Zero
# ## Programa metronomo
# ### Instrucciones:
# ### - Para iniciar estar sobre la casiilla del codigo y darle Run
# ### - Para regresar una opcion precionar el cuadrado a la par de Run

# %%
from time import sleep
import librosa
import sounddevice as sd

tone1 = librosa.tone(880, sr=22050, length=1000)
tone2 = librosa.tone(440, sr=22050, length=1000)
tone3 = librosa.tone(220, sr=22050, length=1000)
a=True
try:
    while a==True:
        print("Bienvenido")
        print("1)2/4")
        print("2)3/4") 
        print("3)4/4")
        print("4)5/4")
        print("5)6/4")
        print("6)7/4")
        opption=input("Ingresar numero de opcion: ")
        if opption=="1":
            bpm=int(input("Ingrese el bpm: "))
            b=True
            print("Desea marcar corcheas")
            print("1)Si")
            print("2)No")
            extra=input("Ingresar numero de opcion: ")
            if extra =="1":
                try:
                    while True:
                        for count in range(2):
#                             print(count)
                            if count == 0:
                                sd.play(tone1, 22050)
                                time = (60 / bpm - 0.1) /2
                                # print(time)
                                sleep(time)
                                sd.play(tone3, 22050)
                                sleep(time)
                            else:
                                sd.play(tone2, 22050)
                                time = (60 / bpm - 0.1) /2
                                # print(time)
                                sleep(time)
                                sd.play(tone3, 22050)
                                sleep(time)
                except KeyboardInterrupt:
                    b=False
            if extra =="2":
                try:
                    while True:
                        for count in range(2):
                            # print(count)
                            if count == 0:
                                sd.play(tone1, 22050)
                                time = (60 / bpm - 0.1)
                                # print(time)
                                sleep(time)
                            else:
                                sd.play(tone2, 22050)
                                time = (60 / bpm - 0.1)
                                # print(time)
                                sleep(time)
                except KeyboardInterrupt:
                    b=False
        if opption=="2":
            bpm=int(input("Ingrese el bpm: "))
            b=True
            print("Desea marcar corcheas")
            print("1)Si")
            print("2)No")
            extra=input("Ingresar numero de opcion: ")
            if extra =="1":
                try:
                    while True:
                        for count in range(3):
                            # print(count)
                            if count == 0:
                                sd.play(tone1, 22050)
                                time = (60 / bpm - 0.1) /2
                                # print(time)
                                sleep(time)
                                sd.play(tone3, 22050)
                                sleep(time)
                            else:
                                sd.play(tone2, 22050)
                                time = (60 / bpm - 0.1) /2
                                # print(time)
                                sleep(time)
                                sd.play(tone3, 22050)
                                sleep(time)
                except KeyboardInterrupt:
                    b=False
            if extra =="2":
                try:
                    while True:
                        for count in range(3):
                            # print(count)
                            if count == 0:
                                sd.play(tone1, 22050)
                                time = (60 / bpm - 0.1)
                                # print(time)
                                sleep(time)
                            else:
                                sd.play(tone2, 22050)
                                time = (60 / bpm - 0.1)
                                # print(time)
                                sleep(time)
                except KeyboardInterrupt:
                    b=False
        if opption=="3":
            bpm=int(input("Ingrese el bpm: "))
            b=True
            print("Desea marcar corcheas")
            print("1)Si")
            print("2)No")
            extra=input("Ingresar numero de opcion: ")
            if extra =="1":
                try:
                    while True:
                        for count in range(4):
                            # print(count)
                            if count == 0:
                                sd.play(tone1, 22050)
                                time = (60 / bpm - 0.1) /2
                                # print(time)
                                sleep(time)
                                sd.play(tone3, 22050)
                                sleep(time)
                            else:
                                sd.play(tone2, 22050)
                                time = (60 / bpm - 0.1) /2
                                # print(time)
                                sleep(time)
                                sd.play(tone3, 22050)
                                sleep(time)
                except KeyboardInterrupt:
                    b=False
            if extra =="2":
                try:
                    while True:
                        for count in range(4):
                            # print(count)
                            if count == 0:
                                sd.play(tone1, 22050)
                                time = (60 / bpm - 0.1)
                                # print(time)
                                sleep(time)
                            else:
                                sd.play(tone2, 22050)
                                time = (60 / bpm - 0.1)
                                # print(time)
                                sleep(time)
                except KeyboardInterrupt:
                    b=False
        if opption=="4":
            bpm=int(input("Ingrese el bpm: "))
            b=True
            print("Desea marcar corcheas")
            print("1)Si")
            print("2)No")
            extra=input("Ingresar numero de opcion: ")
            if extra =="1":
                try:
                    while True:
                        for count in range(5):
                            # print(count)
                            if count == 0:
                                sd.play(tone1, 22050)
                                time = (60 / bpm - 0.1) /2
                                # print(time)
                                sleep(time)
                                sd.play(tone3, 22050)
                                sleep(time)
                            else:
                                sd.play(tone2, 22050)
                                time = (60 / bpm - 0.1) /2
                                # print(time)
                                sleep(time)
                                sd.play(tone3, 22050)
                                sleep(time)
                except KeyboardInterrupt:
                    b=False
            if extra =="2":
                try:
                    while True:
                        for count in range(5):
                            # print(count)
                            if count == 0:
                                sd.play(tone1, 22050)
                                time = (60 / bpm - 0.1)
                                # print(time)
                                sleep(time)
                            else:
                                sd.play(tone2, 22050)
                                time = (60 / bpm - 0.1)
                                # print(time)
                                sleep(time)
                except KeyboardInterrupt:
                    b=False
        if opption=="5":
            bpm=int(input("Ingrese el bpm: "))
            b=True
            print("Desea marcar corcheas")
            print("1)Si")
            print("2)No")
            extra=input("Ingresar numero de opcion: ")
            if extra =="1":
                try:
                    while True:
                        for count in range(6):
                            print(count)
                            if count == 0:
                                sd.play(tone1, 22050)
                                time = (60 / bpm - 0.1) /2
                                # print(time)
                                sleep(time)
                                sd.play(tone3, 22050)
                                sleep(time)
                            else:
                                sd.play(tone2, 22050)
                                time = (60 / bpm - 0.1) /2
                                # print(time)
                                sleep(time)
                                sd.play(tone3, 22050)
                                sleep(time)
                except KeyboardInterrupt:
                    b=False
            if extra =="2":
                try:
                    while True:
                        for count in range(6):
                            # print(count)
                            if count == 0:
                                sd.play(tone1, 22050)
                                time = (60 / bpm - 0.1)
                                # print(time)
                                sleep(time)
                            else:
                                sd.play(tone2, 22050)
                                time = (60 / bpm - 0.1)
                                # print(time)
                                sleep(time)
                except KeyboardInterrupt:
                    b=False
        if opption=="6":
            bpm=int(input("Ingrese el bpm: "))
            b=True
            print("Desea marcar corcheas")
            print("1)Si")
            print("2)No")
            extra=input("Ingresar numero de opcion: ")
            if extra =="1":
                try:
                    while True:
                        for count in range(7):
                            # print(count)
                            if count == 0:
                                sd.play(tone1, 22050)
                                time = (60 / bpm - 0.1) /2
                                # print(time)
                                sleep(time)
                                sd.play(tone3, 22050)
                                sleep(time)
                            else:
                                sd.play(tone2, 22050)
                                time = (60 / bpm - 0.1) /2
                                # print(time)
                                sleep(time)
                                sd.play(tone3, 22050)
                                sleep(time)
                except KeyboardInterrupt:
                    b=False
            if extra =="2":
                try:
                    while True:
                        for count in range(7):
                            # print(count)
                            if count == 0:
                                sd.play1(tone1, 22050)
                                time = 1(60 / bpm - 0.1)
                                # print(time)
                                sleep(time)
                            else:
                                sd.play(tone2, 22050)
                                time = (60 / bpm - 0.1)
                                # print(time)
                                sleep(time)
                except KeyboardInterrupt:
                    b=False
except KeyboardInterrupt:
    pass
